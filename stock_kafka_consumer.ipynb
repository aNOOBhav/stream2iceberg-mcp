# %%
from confluent_kafka import Consumer
import json

conf = {
    'bootstrap.servers': 'localhost:9092',
    'group.id': 'stock-consumer-group',
    'auto.offset.reset': 'earliest'
}

consumer = Consumer(conf)
consumer.subscribe(['stock_topic'])

try:
    print("Starting consumer...")
    while True:
        msg = consumer.poll(1.0)  # timeout in seconds

        if msg is None:
            continue
        if msg.error():
            print("Consumer error: {}".format(msg.error()))
            continue

        # Decode the JSON payload
        try:
            payload = json.loads(msg.value().decode('utf-8'))
            print("Received:", payload)
        except json.JSONDecodeError:
            print("Failed to decode JSON:", msg.value())

except KeyboardInterrupt:
    print("Consumer interrupted.")

finally:
    consumer.close()

# %%
from confluent_kafka import Consumer
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import s3fs
import json
from datetime import datetime

#MinIO S3-compatible connection (IPv4-safe)
fs = s3fs.S3FileSystem(
    key='admin',
    secret='password',
    client_kwargs={'endpoint_url': 'http://127.0.0.1:9000'}  # use 127.0.0.1 instead of localhost
)

#Confluent Kafka Consumer config (binds to IPv4 explicitly)
conf = {
    'bootstrap.servers': '127.0.0.1:9092',
    'group.id': 'stock-consumer-new-group',
    'auto.offset.reset': 'earliest'
}

consumer = Consumer(conf)
consumer.subscribe(['stockdaily-events'])  # Make sure topic exists and is populated

print("Listening to Confluent Kafka topic...")

# Buffer for partitioned writes
message_buffer = {}

def write_partition_to_minio(trade_date, records):
    if not records:
        return
    df = pd.DataFrame(records)
    table = pa.Table.from_pandas(df)

    file_path = f"lakehouse/stock_stream/trade_date={trade_date}/stocks.parquet"
    with fs.open(file_path, 'wb') as f:
        pq.write_table(table, f)

    print(f"Wrote {len(df)} records to MinIO: {file_path}")

try:
    while True:
        msg = consumer.poll(timeout=1.0)
        if msg is None:
            continue
        if msg.error():
            print("Consumer error:", msg.error())
            continue

        try:
            value = json.loads(msg.value().decode('utf-8'))
            print("Received message:", value)

            trade_date = value.get('trade_date')
            if not trade_date:
                print("Missing trade_date. Skipping message.")
                continue

            if trade_date not in message_buffer:
                message_buffer[trade_date] = []
            message_buffer[trade_date].append(value)

            if len(message_buffer[trade_date]) >= 20:
                write_partition_to_minio(trade_date, message_buffer[trade_date])
                message_buffer[trade_date] = []

        except Exception as e:
            print("Error processing message:", e)

except KeyboardInterrupt:
    print("Stopping consumer and flushing remaining data...")
    for trade_date, records in message_buffer.items():
        write_partition_to_minio(trade_date, records)

finally:
    consumer.close()
# Out:
# Listening to Confluent Kafka topic...
# Received message: {'trade_date': '2025-05-16', 'ticker': 'AAPL', 'open_price': 212.36, 'close_price': 211.26, 'pct_change': -0.52}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'MSFT', 'open_price': 452.05, 'close_price': 454.27, 'pct_change': 0.49}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'GOOGL', 'open_price': 167.73, 'close_price': 166.19, 'pct_change': -0.92}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'AMZN', 'open_price': 206.85, 'close_price': 205.59, 'pct_change': -0.61}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'NVDA', 'open_price': 136.22, 'close_price': 135.4, 'pct_change': -0.6}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'TSLA', 'open_price': 346.24, 'close_price': 349.98, 'pct_change': 1.08}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'META', 'open_price': 637.96, 'close_price': 640.34, 'pct_change': 0.37}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'BRK-B', 'open_price': 509.63, 'close_price': 514.31, 'pct_change': 0.92}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'LLY', 'open_price': 740.0, 'close_price': 757.39, 'pct_change': 2.35}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'JPM', 'open_price': 267.5, 'close_price': 267.56, 'pct_change': 0.02}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'V', 'open_price': 362.95, 'close_price': 365.12, 'pct_change': 0.6}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'UNH', 'open_price': 279.29, 'close_price': 291.91, 'pct_change': 4.52}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'AVGO', 'open_price': 232.32, 'close_price': 228.61, 'pct_change': -1.6}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'MA', 'open_price': 580.43, 'close_price': 583.28, 'pct_change': 0.49}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'JNJ', 'open_price': 149.67, 'close_price': 151.33, 'pct_change': 1.11}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'HD', 'open_price': 380.23, 'close_price': 380.78, 'pct_change': 0.14}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'XOM', 'open_price': 108.65, 'close_price': 108.19, 'pct_change': -0.42}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'PG', 'open_price': 162.65, 'close_price': 163.28, 'pct_change': 0.39}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'COST', 'open_price': 1012.49, 'close_price': 1025.83, 'pct_change': 1.32}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'BAC', 'open_price': 44.34, 'close_price': 44.69, 'pct_change': 0.79}
# Error processing message: The specified bucket does not exist
# %4|1747687297.539|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 606297 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747687297.540|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out FetchRequest in flight (after 603708ms, timeout #0)
# %4|1747687297.540|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747687297.540|FAIL|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: 1 request(s) timed out: disconnect (average rtt 502.602ms) (after 17065788ms in state UP)
# %5|1747687930.123|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 632400ms, timeout #0)
# %4|1747687930.123|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747687930.123|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 1.182ms) (after 17698367ms in state UP)
# %4|1747688567.477|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 606940 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747689194.506|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 627024ms, timeout #0)
# %4|1747689194.506|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747689194.506|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 2.846ms) (after 1264373ms in state UP)
# %4|1747689820.131|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 605147 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747689820.132|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out FetchRequest in flight (after 604136ms, timeout #0)
# %4|1747689820.132|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747689820.132|FAIL|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: 1 request(s) timed out: disconnect (average rtt 520.857ms) (after 2522450ms in state UP)
# %5|1747690448.524|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 627382ms, timeout #0)
# %4|1747690448.524|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747690448.524|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 6.022ms) (after 1254013ms in state UP)
# %4|1747691072.342|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 603464 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747691703.965|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 631620ms, timeout #0)
# %4|1747691703.965|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747691703.965|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 9.716ms) (after 1255433ms in state UP)
# %4|1747692332.131|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 605681 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747692963.685|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 631550ms, timeout #0)
# %4|1747692963.685|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747692963.685|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 12.124ms) (after 1259711ms in state UP)
# %4|1747693600.401|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 603004 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747693945.612|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 345182ms, timeout #0)
# %4|1747693945.612|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747693945.613|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 14.900ms) (after 981923ms in state UP)
# %5|1747694560.043|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 614414ms, timeout #0)
# %4|1747694560.043|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747694560.043|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 14.898ms) (after 614414ms in state UP)
# %5|1747695187.900|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out FetchRequest in flight (after 603861ms, timeout #0)
# %4|1747695187.900|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747695187.900|FAIL|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: 1 request(s) timed out: disconnect (average rtt 575.325ms) (after 5367765ms in state UP)
# %4|1747695187.900|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 604318 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747695826.240|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 638335ms, timeout #0)
# %4|1747695826.240|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747695826.240|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 16.925ms) (after 1266195ms in state UP)
# %4|1747696462.603|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 607038 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747696462.603|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out FetchRequest in flight (after 606647ms, timeout #0)
# %4|1747696462.603|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747696462.603|FAIL|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: 1 request(s) timed out: disconnect (average rtt 575.140ms) (after 1274698ms in state UP)
# %5|1747697422.259|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 958650ms, timeout #0)
# %4|1747697422.259|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747697422.259|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 18.879ms) (after 1596016ms in state UP)
# %5|1747698465.946|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 1043685ms, timeout #0)
# %4|1747698465.946|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747698465.946|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 18.876ms) (after 1043685ms in state UP)
# %4|1747699109.863|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 604296 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747699732.548|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 622681ms, timeout #0)
# %4|1747699732.548|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747699732.548|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 19.921ms) (after 1266601ms in state UP)
# %4|1747700376.840|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 606650 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747700376.841|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out FetchRequest in flight (after 604713ms, timeout #0)
# %4|1747700376.841|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747700376.841|FAIL|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: 1 request(s) timed out: disconnect (average rtt 592.782ms) (after 3914232ms in state UP)
# %5|1747701014.249|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 636394ms, timeout #0)
# %4|1747701014.249|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747701014.249|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 23.216ms) (after 1281696ms in state UP)
# %4|1747701650.980|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 605770 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747702284.390|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 633408ms, timeout #0)
# %4|1747702284.390|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747702284.390|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 24.828ms) (after 1270136ms in state UP)
# %5|1747702911.225|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out FetchRequest in flight (after 604803ms, timeout #0)
# %4|1747702911.225|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747702911.225|FAIL|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: 1 request(s) timed out: disconnect (average rtt 610.645ms) (after 2534370ms in state UP)
# %4|1747702911.225|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 606286 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747703536.717|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 625488ms, timeout #0)
# %4|1747703536.717|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747703536.717|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 27.364ms) (after 1252325ms in state UP)
# %4|1747704181.268|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 603226 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747705140.024|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 958739ms, timeout #0)
# %4|1747705140.024|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747705140.025|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 30.859ms) (after 1603301ms in state UP)
# %4|1747705788.034|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 602070 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747705788.035|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out FetchRequest in flight (after 601845ms, timeout #0)
# %4|1747705788.035|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747705788.035|FAIL|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: 1 request(s) timed out: disconnect (average rtt 628.078ms) (after 2876807ms in state UP)
# %5|1747706417.955|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 629405ms, timeout #0)
# %4|1747706417.955|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747706417.955|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 32.421ms) (after 1277929ms in state UP)
# %4|1747707052.634|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 608690 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %4|1747707722.425|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 606041 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747708605.381|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 882953ms, timeout #0)
# %4|1747708605.381|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747708605.381|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 43.276ms) (after 2187422ms in state UP)
# %4|1747708765.025|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 127943 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747709375.594|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 610566ms, timeout #0)
# %4|1747709375.594|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747709375.594|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 43.916ms) (after 770208ms in state UP)
# %5|1747710000.277|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 624674ms, timeout #0)
# %4|1747710000.277|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747710000.277|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 43.908ms) (after 624674ms in state UP)
# %5|1747710624.985|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out FetchRequest in flight (after 602176ms, timeout #0)
# %4|1747710624.985|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747710624.985|FAIL|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: 1 request(s) timed out: disconnect (average rtt 667.105ms) (after 4836938ms in state UP)
# %4|1747710624.985|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 602631 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747711573.811|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 948823ms, timeout #0)
# %4|1747711573.811|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747711573.811|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 46.097ms) (after 1573533ms in state UP)
# %4|1747712097.821|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 482733 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747712711.398|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 613569ms, timeout #0)
# %4|1747712711.398|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747712711.398|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 49.496ms) (after 1137585ms in state UP)
# %5|1747713348.923|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 637523ms, timeout #0)
# %4|1747713348.923|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747713348.923|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 49.487ms) (after 637523ms in state UP)
# %4|1747713980.395|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 603731 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747713980.395|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out FetchRequest in flight (after 601892ms, timeout #0)
# %4|1747713980.395|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747713980.395|FAIL|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: 1 request(s) timed out: disconnect (average rtt 680.605ms) (after 3355407ms in state UP)
# %5|1747714614.864|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 633457ms, timeout #0)
# %4|1747714614.864|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747714614.865|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 49.368ms) (after 1265938ms in state UP)
# %5|1747715239.109|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out FetchRequest in flight (after 601904ms, timeout #0)
# %4|1747715239.109|REQTMOUT|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747715239.109|FAIL|rdkafka#consumer-1| [thrd:localhost:9092/1]: localhost:9092/1: 1 request(s) timed out: disconnect (average rtt 680.354ms) (after 1258704ms in state UP)
# %4|1747715239.109|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 603395 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %4|1747715767.725|SESSTMOUT|rdkafka#consumer-1| [thrd:main]: Consumer group session timed out (in join-state steady) after 470215 ms without a successful response from the group coordinator (broker 1, last error was Success): revoking assignment and rejoining group
# %5|1747716420.415|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out JoinGroupRequest in flight (after 652686ms, timeout #0)
# %4|1747716420.415|REQTMOUT|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator/1: Timed out 1 in-flight, 0 retry-queued, 0 out-queue, 0 partially-sent requests
# %3|1747716420.415|FAIL|rdkafka#consumer-1| [thrd:GroupCoordinator]: GroupCoordinator: localhost:9092: 1 request(s) timed out: disconnect (average rtt 58.703ms) (after 1805523ms in state UP)
# Received message: {'trade_date': '2025-05-16', 'ticker': 'AAPL', 'open_price': 212.36, 'close_price': 211.26, 'pct_change': -0.52}
# Wrote 21 records to MinIO: lakehouse/stock_stream/trade_date=2025-05-16/stocks.parquet
# Received message: {'trade_date': '2025-05-16', 'ticker': 'MSFT', 'open_price': 452.05, 'close_price': 454.27, 'pct_change': 0.49}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'GOOGL', 'open_price': 167.73, 'close_price': 166.19, 'pct_change': -0.92}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'AMZN', 'open_price': 206.85, 'close_price': 205.59, 'pct_change': -0.61}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'NVDA', 'open_price': 136.22, 'close_price': 135.4, 'pct_change': -0.6}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'TSLA', 'open_price': 346.24, 'close_price': 349.98, 'pct_change': 1.08}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'META', 'open_price': 637.96, 'close_price': 640.34, 'pct_change': 0.37}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'BRK-B', 'open_price': 509.63, 'close_price': 514.31, 'pct_change': 0.92}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'LLY', 'open_price': 740.0, 'close_price': 757.39, 'pct_change': 2.35}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'JPM', 'open_price': 267.5, 'close_price': 267.56, 'pct_change': 0.02}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'V', 'open_price': 362.95, 'close_price': 365.12, 'pct_change': 0.6}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'UNH', 'open_price': 279.29, 'close_price': 291.91, 'pct_change': 4.52}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'AVGO', 'open_price': 232.32, 'close_price': 228.61, 'pct_change': -1.6}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'MA', 'open_price': 580.43, 'close_price': 583.28, 'pct_change': 0.49}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'JNJ', 'open_price': 149.67, 'close_price': 151.33, 'pct_change': 1.11}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'HD', 'open_price': 380.23, 'close_price': 380.78, 'pct_change': 0.14}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'XOM', 'open_price': 108.65, 'close_price': 108.19, 'pct_change': -0.42}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'PG', 'open_price': 162.65, 'close_price': 163.28, 'pct_change': 0.39}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'COST', 'open_price': 1012.49, 'close_price': 1025.83, 'pct_change': 1.32}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'BAC', 'open_price': 44.34, 'close_price': 44.69, 'pct_change': 0.79}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'AAPL', 'open_price': 207.91, 'close_price': 208.78, 'pct_change': 0.42}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'MSFT', 'open_price': 450.88, 'close_price': 458.87, 'pct_change': 1.77}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'GOOGL', 'open_price': 164.51, 'close_price': 166.54, 'pct_change': 1.23}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'AMZN', 'open_price': 201.65, 'close_price': 206.16, 'pct_change': 2.24}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'NVDA', 'open_price': 132.39, 'close_price': 135.57, 'pct_change': 2.4}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'TSLA', 'open_price': 336.3, 'close_price': 342.09, 'pct_change': 1.72}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'META', 'open_price': 628.25, 'close_price': 640.43, 'pct_change': 1.94}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'BRK-B', 'open_price': 513.62, 'close_price': 512.39, 'pct_change': -0.24}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'LLY', 'open_price': 753.0, 'close_price': 755.11, 'pct_change': 0.28}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'JPM', 'open_price': 265.55, 'close_price': 264.88, 'pct_change': -0.25}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'V', 'open_price': 363.02, 'close_price': 367.9, 'pct_change': 1.34}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'UNH', 'open_price': 304.77, 'close_price': 315.89, 'pct_change': 3.65}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'AVGO', 'open_price': 221.85, 'close_price': 230.63, 'pct_change': 3.96}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'MA', 'open_price': 581.02, 'close_price': 586.41, 'pct_change': 0.93}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'JNJ', 'open_price': 151.89, 'close_price': 152.49, 'pct_change': 0.4}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'HD', 'open_price': 374.19, 'close_price': 379.38, 'pct_change': 1.39}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'XOM', 'open_price': 107.57, 'close_price': 106.47, 'pct_change': -1.02}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'PG', 'open_price': 163.47, 'close_price': 164.77, 'pct_change': 0.8}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'COST', 'open_price': 1018.6, 'close_price': 1034.34, 'pct_change': 1.55}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'BAC', 'open_price': 44.11, 'close_price': 44.77, 'pct_change': 1.5}
# Wrote 20 records to MinIO: lakehouse/stock_stream/trade_date=2025-05-19/stocks.parquet
# Received message: {'trade_date': '2025-05-16', 'ticker': 'AAPL', 'open_price': 212.36, 'close_price': 211.26, 'pct_change': -0.52}
# Wrote 20 records to MinIO: lakehouse/stock_stream/trade_date=2025-05-16/stocks.parquet
# Received message: {'trade_date': '2025-05-16', 'ticker': 'MSFT', 'open_price': 452.05, 'close_price': 454.27, 'pct_change': 0.49}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'GOOGL', 'open_price': 167.73, 'close_price': 166.19, 'pct_change': -0.92}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'AMZN', 'open_price': 206.85, 'close_price': 205.59, 'pct_change': -0.61}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'NVDA', 'open_price': 136.22, 'close_price': 135.4, 'pct_change': -0.6}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'TSLA', 'open_price': 346.24, 'close_price': 349.98, 'pct_change': 1.08}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'META', 'open_price': 637.96, 'close_price': 640.34, 'pct_change': 0.37}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'BRK-B', 'open_price': 509.63, 'close_price': 514.31, 'pct_change': 0.92}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'LLY', 'open_price': 740.0, 'close_price': 757.39, 'pct_change': 2.35}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'JPM', 'open_price': 267.5, 'close_price': 267.56, 'pct_change': 0.02}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'V', 'open_price': 362.95, 'close_price': 365.12, 'pct_change': 0.6}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'UNH', 'open_price': 279.29, 'close_price': 291.91, 'pct_change': 4.52}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'AVGO', 'open_price': 232.32, 'close_price': 228.61, 'pct_change': -1.6}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'MA', 'open_price': 580.43, 'close_price': 583.28, 'pct_change': 0.49}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'JNJ', 'open_price': 149.67, 'close_price': 151.33, 'pct_change': 1.11}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'HD', 'open_price': 380.23, 'close_price': 380.78, 'pct_change': 0.14}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'XOM', 'open_price': 108.65, 'close_price': 108.19, 'pct_change': -0.42}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'PG', 'open_price': 162.65, 'close_price': 163.28, 'pct_change': 0.39}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'COST', 'open_price': 1012.49, 'close_price': 1025.83, 'pct_change': 1.32}
# Received message: {'trade_date': '2025-05-16', 'ticker': 'BAC', 'open_price': 44.34, 'close_price': 44.69, 'pct_change': 0.79}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'AAPL', 'open_price': 207.91, 'close_price': 208.78, 'pct_change': 0.42}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'MSFT', 'open_price': 450.88, 'close_price': 458.87, 'pct_change': 1.77}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'GOOGL', 'open_price': 164.51, 'close_price': 166.54, 'pct_change': 1.23}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'AMZN', 'open_price': 201.65, 'close_price': 206.16, 'pct_change': 2.24}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'NVDA', 'open_price': 132.39, 'close_price': 135.57, 'pct_change': 2.4}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'TSLA', 'open_price': 336.3, 'close_price': 342.09, 'pct_change': 1.72}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'META', 'open_price': 628.25, 'close_price': 640.43, 'pct_change': 1.94}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'BRK-B', 'open_price': 513.62, 'close_price': 512.39, 'pct_change': -0.24}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'LLY', 'open_price': 753.0, 'close_price': 755.11, 'pct_change': 0.28}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'JPM', 'open_price': 265.55, 'close_price': 264.88, 'pct_change': -0.25}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'V', 'open_price': 363.02, 'close_price': 367.9, 'pct_change': 1.34}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'UNH', 'open_price': 304.77, 'close_price': 315.89, 'pct_change': 3.65}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'AVGO', 'open_price': 221.85, 'close_price': 230.63, 'pct_change': 3.96}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'MA', 'open_price': 581.02, 'close_price': 586.41, 'pct_change': 0.93}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'JNJ', 'open_price': 151.89, 'close_price': 152.49, 'pct_change': 0.4}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'HD', 'open_price': 374.19, 'close_price': 379.38, 'pct_change': 1.39}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'XOM', 'open_price': 107.57, 'close_price': 106.47, 'pct_change': -1.02}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'PG', 'open_price': 163.47, 'close_price': 164.77, 'pct_change': 0.8}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'COST', 'open_price': 1018.6, 'close_price': 1034.34, 'pct_change': 1.55}
# Received message: {'trade_date': '2025-05-19', 'ticker': 'BAC', 'open_price': 44.11, 'close_price': 44.77, 'pct_change': 1.5}
# Wrote 20 records to MinIO: lakehouse/stock_stream/trade_date=2025-05-19/stocks.parquet

# %%
import s3fs
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq

fs = s3fs.S3FileSystem(
    key='admin',
    secret='password',
    client_kwargs={'endpoint_url': 'http://localhost:9000'}
)

df = pd.DataFrame({"symbol": ["AAPL"], "price": [185.32]})
table = pa.Table.from_pandas(df)
with fs.open('lakehouse/test/aapl.parquet', 'wb') as f:
    pq.write_table(table, f)

print("Test file written.")

# %%
from confluent_kafka import Consumer
import pandas as pd
import pyarrow as pa
import pyarrow.parquet as pq
import s3fs
import json

fs = s3fs.S3FileSystem(
    key='admin',
    secret='password',
    client_kwargs={'endpoint_url': 'http://localhost:9000'}
)

conf = {
    'bootstrap.servers': 'localhost:9092',
    'group.id': 'stock-consumer-group',
    'auto.offset.reset': 'earliest'
}

consumer = Consumer(conf)
consumer.subscribe(['stock_topic'])

print("Listening to Confluent Kafka topic...")

message_buffer = {}

def write_partition_to_minio(trade_date, records):
    if not records:
        return
    df = pd.DataFrame(records)
    table = pa.Table.from_pandas(df)

    file_path = f"lakehouse/stock_stream/trade_date={trade_date}/stocks.parquet"
    with fs.open(file_path, 'wb') as f:
        pq.write_table(table, f)

    print(f"Wrote {len(df)} records to MinIO: {file_path}")

try:
    while True:
        msg = consumer.poll(timeout=1.0)
        if msg is None:
            continue
        if msg.error():
            print("Consumer error:", msg.error())
            continue

        value = json.loads(msg.value().decode('utf-8'))
        print("Received message:", value)

        trade_date = value.get('trade_date')
        if not trade_date:
            print("Missing trade_date. Skipping message.")
            continue

        message_buffer.setdefault(trade_date, []).append(value)

except KeyboardInterrupt:
    print("Stopping consumer and flushing remaining data...")
    for trade_date, records in message_buffer.items():
        write_partition_to_minio(trade_date, records)

finally:
    consumer.close()

# %%
from confluent_kafka import Producer
import yfinance as yf
import json
from datetime import datetime, timedelta

conf = {'bootstrap.servers': '127.0.0.1:9092'}
producer = Producer(conf)

TICKERS = [ 'AAPL', 'MSFT', 'GOOGL', 'AMZN', 'NVDA',
            'TSLA', 'META', 'BRK-B', 'LLY', 'JPM',
            'V', 'UNH', 'AVGO', 'MA', 'JNJ',
            'HD', 'XOM', 'PG', 'COST', 'BAC' ]

def delivery_report(err, msg):
    if err:
        print(f"Delivery failed for {msg.key()}: {err}")
    else:
        print(f"Delivered {msg.key().decode()} to {msg.topic()} [{msg.partition()}]")

for ticker in TICKERS:
    data = yf.download(ticker, period="3d", interval="1d", progress=False)
    if len(data) < 2:
        continue
    row = data.iloc[-1]
    trade_date = row.name.strftime('%Y-%m-%d')

    payload = {
        "trade_date": trade_date,
        "ticker": ticker,
        "open_price": round(float(row['Open']), 2),
        "close_price": round(float(row['Close']), 2),
        "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
    }

    producer.produce("stockdaily-events", key=ticker.encode(), value=json.dumps(payload), callback=delivery_report)

producer.flush()
# Out:
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# Delivered AAPL to stockdaily-events [0]
# Delivered MSFT to stockdaily-events [0]
# Delivered GOOGL to stockdaily-events [0]
# Delivered AMZN to stockdaily-events [0]
# Delivered NVDA to stockdaily-events [0]
# Delivered TSLA to stockdaily-events [0]
# Delivered META to stockdaily-events [0]
# Delivered BRK-B to stockdaily-events [0]
# Delivered LLY to stockdaily-events [0]
# Delivered JPM to stockdaily-events [0]
# Delivered V to stockdaily-events [0]
# Delivered UNH to stockdaily-events [0]
# Delivered AVGO to stockdaily-events [0]
# Delivered MA to stockdaily-events [0]
# Delivered JNJ to stockdaily-events [0]
# Delivered HD to stockdaily-events [0]
# Delivered XOM to stockdaily-events [0]
# Delivered PG to stockdaily-events [0]
# Delivered COST to stockdaily-events [0]
# Delivered BAC to stockdaily-events [0]
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:30: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "open_price": round(float(row['Open']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:31: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "close_price": round(float(row['Close']), 2),
# /var/folders/q_/9nb7l4k94xsf_7tzcg7203xr0000gp/T/ipykernel_96982/2785572883.py:32: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   "pct_change": round(float((row['Close'] - row['Open']) / row['Open']) * 100, 2)
# 0

# %%
from confluent_kafka import Producer

conf = {
    'bootstrap.servers': 'localhost:9092'
}

producer = Producer(conf)
producer.flush()
# Out:
# 0
